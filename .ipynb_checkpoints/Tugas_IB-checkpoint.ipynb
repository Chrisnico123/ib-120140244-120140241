# %%
# Impor semua library yang diperlukan
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sklearn as sklearn
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# Muat Dataset ke dalam Lingkungan Python
df = pd.read_csv("C:/Users/ASUS/Documents/My_Journey/Jupiter/healthcare-dataset-stroke-data.csv")
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df = df.dropna()
# Menghilangkan kolom 'id'
df = df.drop(['id'], axis=1)
# Visualisasi data untuk memahami distribusi fitur
fig, axes = plt.subplots(2, 2, figsize=(15, 8))
sns.histplot(data=df, x='stroke', ax=axes[0, 0], color='skyblue')
sns.histplot(data=df, x='gender', ax=axes[0, 1], color='skyblue')
sns.histplot(data=df, x='age', ax=axes[1, 0], color='skyblue')
sns.histplot(data=df, x='work_type', ax=axes[1, 1], color='skyblue')
plt.show()

# %%
# 4. Implementasi SMOTE untuk oversampling.

# Identifikasi kolom kategorikal
categorical_columns = df.select_dtypes(include=['object']).columns

# Lakukan encoding one-hot untuk kolom kategorikal
df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# Memisahkan fitur (x) dan label (y)
x = df.drop(['stroke'], axis=1)
y = df['stroke']

# Melakukan oversampling dengan SMOTE
sm = SMOTE(random_state=30)
x_sampling, y_sampling = sm.fit_resample(x, y)

# Visualisasi distribusi label setelah SMOTE
fig = plt.subplots(figsize=(9, 6))
sns.histplot(data=y_sampling)
plt.show()

# %%
# # 5. Bagi dataset menjadi data training dan testing.

# Membuat dan melatih model Decision Tree untuk data asli
dt_classifier_orig = DecisionTreeClassifier()
dt_classifier_orig.fit(x_train_orig, y_train_orig)

# Membuat dan melatih model Decision Tree untuk data resampled
dt_classifier_res = DecisionTreeClassifier()
dt_classifier_res.fit(x_train_res, y_train_res)

# Membuat dan melatih model Random Forest untuk data asli
rf_classifier_orig = RandomForestClassifier()
rf_classifier_orig.fit(x_train_orig, y_train_orig)

# Membuat dan melatih model Random Forest untuk data resampled
rf_classifier_res = RandomForestClassifier()
rf_classifier_res.fit(x_train_res, y_train_res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 # # 5. Bagi dataset menjadi data training dan testing.
#       2
#       3 # Membuat dan melatih model Decision Tree untuk data asli
#       4 dt_classifier_orig = DecisionTreeClassifier()
# ----> 5 dt_classifier_orig.fit(x_train_orig, y_train_orig)
#       7 # Membuat dan melatih model Decision Tree untuk data resampled
#       8 dt_classifier_res = DecisionTreeClassifier()
#
# NameError: name 'x_train_orig' is not defined

# %%
# 7. Evaluasi kinerja setiap model.
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1-score:", f1_score(y_test, y_pred))
    print("AUC-ROC:", roc_auc_score(y_test, y_pred))
    print("-----------------------------")

print("Metrics for Decision Tree on Original Data:")
evaluate_model(dt_classifier_orig, x_test_orig, y_test_orig)

print("Metrics for Decision Tree on Resampled Data:")
evaluate_model(dt_classifier_res, x_test_res, y_test_res)

print("Metrics for Random Forest on Original Data:")
evaluate_model(rf_classifier_orig, x_test_orig, y_test_orig)

print("Metrics for Random Forest on Resampled Data:")
evaluate_model(rf_classifier_res, x_test_res, y_test_res)
# Out:
# Metrics for Decision Tree on Original Data:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       9     print("-----------------------------")
#      11 print("Metrics for Decision Tree on Original Data:")
# ---> 12 evaluate_model(dt_classifier_orig, x_test_orig, y_test_orig)
#      14 print("Metrics for Decision Tree on Resampled Data:")
#      15 evaluate_model(dt_classifier_res, x_test_res, y_test_res)
#
# NameError: name 'x_test_orig' is not defined
